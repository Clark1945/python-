# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# df=pd.read_excel("712693030RPKUP4RX.xlsx",header=3) #從第四列開始
# df=df[["縣市名稱","區里代碼","區鄉鎮名稱"]]
# df.to_excel('district.xlsx',encoding='utf-8',index=False)

url='https://www.cwb.gov.tw/V8/C/W/Town/MOD/3hr/1000401_3hr_PC.html?T=2022120917-1'
# df=pd.read_html(url)[0]
geturl=requests.get(url)
if geturl.status_code != 200:
    print("未成功訪問")
soup=BeautifulSoup(geturl.text,'html.parser')
all_data = soup.find_all("tr")

# %%
measurement_columns=[]
measurement_date=[]
measurement_time=[]
measurement_weather=[]
measurement_temperature=[]
measurement_bodyTemperature=[]
measurement_rain=[]
measurement_wet=[]
measurement_wind=[]
measurement_windS=[]
measurement_windDirection=[]
measurement_comfort=[]

for x in range(len(all_data)):
    measurement_columns.append(all_data[x].th.text)
    if all_data[x].th.text=="日期":
        for y in range(1,len(all_data[x].find_all('th'))):
            measurement_date.append(all_data[x].find_all('th')[y].text)
    if all_data[x].th.text=="時間":
        for y in range(1,len(all_data[x].find_all('th'))):
            measurement_time.append(all_data[x].find_all('th')[y].text)
    if all_data[x].th.text=="天氣狀況":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_weather.append(all_data[x].find_all('td')[y].img.get("title"))
    if all_data[x].th.text=="溫度":
        for y in range(len(all_data[x].find_all('td'))):
            temperature = all_data[x].find_all('td')[y].text[0:2]
            measurement_temperature.append(temperature)
    if all_data[x].th.text=="體感溫度":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_bodyTemperature.append(all_data[x].find_all('td')[y].text[0:2])
    if all_data[x].th.text=="降雨機率":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_rain.append(all_data[x].find_all('td')[y].text)
            # measurement_temperature.append(temperature)
    if all_data[x].th.text=="相對濕度":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_wet.append(all_data[x].find_all('td')[y].text)
    if all_data[x].th.text=="蒲福風級":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_wind.append(all_data[x].find_all('td')[y].text)
    if all_data[x].th.text=="風速(m/s)":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_windS.append(all_data[x].find_all('td')[y].text)
    if all_data[x].th.text=="風向":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_windDirection.append(all_data[x].find_all('td')[y].text)
    if all_data[x].th.text=="舒適度":
        for y in range(len(all_data[x].find_all('td'))):
            measurement_comfort.append(all_data[x].find_all('td')[y].text)
    

len(measurement_columns),len(measurement_date),len(measurement_time),len(measurement_weather),len(measurement_temperature),len(measurement_bodyTemperature),len(measurement_rain),len(measurement_wet),len(measurement_wind),len(measurement_windS),len(measurement_windDirection),len(measurement_comfort)
# measurement_rain
# Out:
# (11, 3, 17, 17, 17, 17, 9, 17, 17, 17, 17, 17)

# %%
import pandas as pd
df=pd.DataFrame(columns=measurement_columns)
# df["日期"]=measurement_date
df["時間"]=measurement_time
df["天氣狀況"]=measurement_weather
df["溫度"]=measurement_temperature
df["體感溫度"]=measurement_bodyTemperature
# df["降雨機率"]=measurement_rain
df["相對濕度"]=measurement_wet
df["蒲福風級"]=measurement_wind
df["風速(m/s)"]=measurement_windS
df["風向"]=measurement_windDirection
df["舒適度"]=measurement_comfort
df
# Out:
#      日期     時間 天氣狀況  溫度 體感溫度 降雨機率 相對濕度 蒲福風級 風速(m/s)   風向   舒適度
# 0   NaN  18:00  短暫雨  19   20  NaN  90%    2       3  東北風  稍有寒意
# 1   NaN  21:00   多雲  19   19  NaN  91%    2       3  東北風  稍有寒意
# 2   NaN  00:00   多雲  19   19  NaN  91%    3       4  東北風  稍有寒意
# 3   NaN  03:00   多雲  19   19  NaN  91%    3       4  東北風  稍有寒意
# 4   NaN  06:00  短暫雨  18   18  NaN  90%    3       4  東北風  稍有寒意
# 5   NaN  09:00   多雲  20   19  NaN  87%    3       5  東北風  稍有寒意
# 6   NaN  12:00  短暫雨  21   20  NaN  82%    3       5  東北風    舒適
# 7   NaN  15:00   多雲  20   20  NaN  83%    3       4  東北風  稍有寒意
# 8   NaN  18:00  短暫雨  18   18  NaN  88%    3       4  東北風  稍有寒意
# 9   NaN  21:00  短暫雨  18   17  NaN  91%    3       4  東北風  稍有寒意
# 10  NaN  00:00  短暫雨  18   18  NaN  92%    3       4  東北風  稍有寒意
# 11  NaN  03:00  短暫雨  17   17  NaN  93%    3       4  東北風  稍有寒意
# 12  NaN  06:00  短暫雨  17   17  NaN  94%    3       5  東北風  稍有寒意
# 13  NaN  09:00  短暫雨  18   17  NaN  91%    3       5  東北風  稍有寒意
# 14  NaN  12:00  短暫雨  18   17  NaN  86%    4       6  東北風  稍有寒意
# 15  NaN  15:00  短暫雨  18   17  NaN  85%    3       5  東北風  稍有寒意
# 16  NaN  18:00  短暫雨  17   16  NaN  87%    3       5  東北風  稍有寒意

# %%
measurement_time
measurement_date
temp_date=[]
cnt=0
for x in range(len(measurement_time)):
    # print(measurement_time[x])
    if measurement_time[x] != "00:00":
        temp_date.append(measurement_date[cnt])
    else:
        cnt+=1
        temp_date.append(measurement_date[cnt])      
df["日期"]=temp_date
df
# Out:
#           日期     時間 天氣狀況  溫度 體感溫度 降雨機率 相對濕度 蒲福風級 風速(m/s)   風向   舒適度
# 0   12/09星期五  18:00  短暫雨  19   20  NaN  90%    2       3  東北風  稍有寒意
# 1   12/09星期五  21:00   多雲  19   19  NaN  91%    2       3  東北風  稍有寒意
# 2   12/10星期六  00:00   多雲  19   19  NaN  91%    3       4  東北風  稍有寒意
# 3   12/10星期六  03:00   多雲  19   19  NaN  91%    3       4  東北風  稍有寒意
# 4   12/10星期六  06:00  短暫雨  18   18  NaN  90%    3       4  東北風  稍有寒意
# 5   12/10星期六  09:00   多雲  20   19  NaN  87%    3       5  東北風  稍有寒意
# 6   12/10星期六  12:00  短暫雨  21   20  NaN  82%    3       5  東北風    舒適
# 7   12/10星期六  15:00   多雲  20   20  NaN  83%    3       4  東北風  稍有寒意
# 8   12/10星期六  18:00  短暫雨  18   18  NaN  88%    3       4  東北風  稍有寒意
# 9   12/10星期六  21:00  短暫雨  18   17  NaN  91%    3       4  東北風  稍有寒意
# 10  12/11星期日  00:00  短暫雨  18   18  NaN  92%    3       4  東北風  稍有寒意
# 11  12/11星期日  03:00  短暫雨  17   17  NaN  93%    3       4  東北風  稍有寒意
# 12  12/11星期日  06:00  短暫雨  17   17  NaN  94%    3       5  東北風  稍有寒意
# 13  12/11星期日  09:00  短暫雨  18   17  NaN  91%    3       5  東北風  稍有寒意
# 14  12/11星期日  12:00  短暫雨  18   17  NaN  86%    4       6  東北風  稍有寒意
# 15  12/11星期日  15:00  短暫雨  18   17  NaN  85%    3       5  東北風  稍有寒意
# 16  12/11星期日  18:00  短暫雨  17   16  NaN  87%    3       5  東北風  稍有寒意

# %%
measurement_rain2=[]
for x in range(len(measurement_rain)):
    measurement_rain2.append(measurement_rain[x])
    measurement_rain2.append(measurement_rain[x])
measurement_rain2=measurement_rain2[:len(measurement_rain2)-1]
df["降雨機率"]=measurement_rain2
df
# Out:
#           日期     時間 天氣狀況  溫度 體感溫度 降雨機率 相對濕度 蒲福風級 風速(m/s)   風向   舒適度
# 0   12/09星期五  18:00  短暫雨  19   20  30%  90%    2       3  東北風  稍有寒意
# 1   12/09星期五  21:00   多雲  19   19  30%  91%    2       3  東北風  稍有寒意
# 2   12/10星期六  00:00   多雲  19   19  10%  91%    3       4  東北風  稍有寒意
# 3   12/10星期六  03:00   多雲  19   19  10%  91%    3       4  東北風  稍有寒意
# 4   12/10星期六  06:00  短暫雨  18   18  30%  90%    3       4  東北風  稍有寒意
# 5   12/10星期六  09:00   多雲  20   19  30%  87%    3       5  東北風  稍有寒意
# 6   12/10星期六  12:00  短暫雨  21   20  30%  82%    3       5  東北風    舒適
# 7   12/10星期六  15:00   多雲  20   20  30%  83%    3       4  東北風  稍有寒意
# 8   12/10星期六  18:00  短暫雨  18   18  40%  88%    3       4  東北風  稍有寒意
# 9   12/10星期六  21:00  短暫雨  18   17  40%  91%    3       4  東北風  稍有寒意
# 10  12/11星期日  00:00  短暫雨  18   18  30%  92%    3       4  東北風  稍有寒意
# 11  12/11星期日  03:00  短暫雨  17   17  30%  93%    3       4  東北風  稍有寒意
# 12  12/11星期日  06:00  短暫雨  17   17  30%  94%    3       5  東北風  稍有寒意
# 13  12/11星期日  09:00  短暫雨  18   17  30%  91%    3       5  東北風  稍有寒意
# 14  12/11星期日  12:00  短暫雨  18   17  30%  86%    4       6  東北風  稍有寒意
# 15  12/11星期日  15:00  短暫雨  18   17  30%  85%    3       5  東北風  稍有寒意
# 16  12/11星期日  18:00  短暫雨  17   16  30%  87%    3       5  東北風  稍有寒意

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

if not os.path.isfile('district.xlsx'):
    df=pd.read_excel("712693030RPKUP4RX.xlsx",header=3) #從第四列開始
    df=df[["縣市名稱","區里代碼","區鄉鎮名稱"]]
    df=df.drop_duplicates()
    df.to_excel('district.xlsx',encoding='utf-8',index=False)
df_town=pd.read_excel('district.xlsx')
town="新竹縣竹北市"
dfs=df_town[(df_town["縣市名稱"]==town[0:3])&(df_town["區鄉鎮名稱"]==town[3:])]

if len(dfs)>0:
    town_no=str(dfs.iloc[0,1])# 區里代碼
    url='https://www.cwb.gov.tw/V8/C/W/Town/MOD/3hr/'+town_no+'_3hr_PC.html?T=2022120917-1'
    geturl=requests.get(url)
    if geturl.status_code != 200:
        print("未成功訪問")
    soup=BeautifulSoup(geturl.text,'html.parser')
    all_data = soup.find_all("tr")

    measurement_columns=[]
    measurement_date=[]
    measurement_time=[]
    measurement_weather=[]
    measurement_temperature=[]
    measurement_bodyTemperature=[]
    measurement_rain=[]
    measurement_wet=[]
    measurement_wind=[]
    measurement_windS=[]
    measurement_windDirection=[]
    measurement_comfort=[]

    for x in range(len(all_data)):
        measurement_columns.append(all_data[x].th.text)
        if all_data[x].th.text=="日期":
            for y in range(1,len(all_data[x].find_all('th'))):
                measurement_date.append(all_data[x].find_all('th')[y].text)
        if all_data[x].th.text=="時間":
            for y in range(1,len(all_data[x].find_all('th'))):
                measurement_time.append(all_data[x].find_all('th')[y].text)
        if all_data[x].th.text=="天氣狀況":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_weather.append(all_data[x].find_all('td')[y].img.get("title"))
        if all_data[x].th.text=="溫度":
            for y in range(len(all_data[x].find_all('td'))):
                temperature = all_data[x].find_all('td')[y].text[0:2]
                measurement_temperature.append(temperature)
        if all_data[x].th.text=="體感溫度":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_bodyTemperature.append(all_data[x].find_all('td')[y].text[0:2])
        if all_data[x].th.text=="降雨機率":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_rain.append(all_data[x].find_all('td')[y].text)
                # measurement_temperature.append(temperature)
        if all_data[x].th.text=="相對濕度":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_wet.append(all_data[x].find_all('td')[y].text)
        if all_data[x].th.text=="蒲福風級":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_wind.append(all_data[x].find_all('td')[y].text)
        if all_data[x].th.text=="風速(m/s)":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_windS.append(all_data[x].find_all('td')[y].text)
        if all_data[x].th.text=="風向":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_windDirection.append(all_data[x].find_all('td')[y].text)
        if all_data[x].th.text=="舒適度":
            for y in range(len(all_data[x].find_all('td'))):
                measurement_comfort.append(all_data[x].find_all('td')[y].text) 
    import pandas as pd
    df=pd.DataFrame(columns=measurement_columns)

    temp_date=[]
    cnt=0
    for x in range(len(measurement_time)):
        if measurement_time[x] != "00:00":
            temp_date.append(measurement_date[cnt])
        else:
            cnt+=1
            temp_date.append(measurement_date[cnt])      
    

    measurement_rain2=[]
    for x in range(len(measurement_rain)):
        measurement_rain2.append(measurement_rain[x])
        measurement_rain2.append(measurement_rain[x])
    measurement_rain2=measurement_rain2[:len(measurement_rain2)-1]
    

    df["日期"]=temp_date
    df["時間"]=measurement_time
    df["天氣狀況"]=measurement_weather
    df["溫度"]=measurement_temperature
    df["體感溫度"]=measurement_bodyTemperature
    df["降雨機率"]=measurement_rain2
    df["相對濕度"]=measurement_wet
    df["蒲福風級"]=measurement_wind
    df["風速(m/s)"]=measurement_windS
    df["風向"]=measurement_windDirection
    df["舒適度"]=measurement_comfort
    print(df.to_json(orient='records',force_ascii=False)) #將所有資料用JSON格式回傳
else:
    print("無此名稱")
# Out:
# [{"日期":"12\/09星期五","時間":"21:00","天氣狀況":"陰","溫度":"19","體感溫度":"19","降雨機率":"30%","相對濕度":"91%","蒲福風級":"2","風速(m\/s)":"3","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/10星期六","時間":"00:00","天氣狀況":"多雲","溫度":"19","體感溫度":"19","降雨機率":"30%","相對濕度":"91%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/10星期六","時間":"03:00","天氣狀況":"陰","溫度":"18","體感溫度":"18","降雨機率":"20%","相對濕度":"91%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/10星期六","時間":"06:00","天氣狀況":"短暫雨","溫度":"18","體感溫度":"18","降雨機率":"20%","相對濕度":"90%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/10星期六","時間":"09:00","天氣狀況":"多雲","溫度":"19","體感溫度":"19","降雨機率":"30%","相對濕度":"87%","蒲福風級":"3","風速(m\/s)":"5","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/10星期六","時間":"12:00","天氣狀況":"短暫雨","溫度":"21","體感溫度":"20","降雨機率":"30%","相對濕度":"82%","蒲福風級":"3","風速(m\/s)":"5","風向":"東北風","舒適度":"舒適"},{"日期":"12\/10星期六","時間":"15:00","天氣狀況":"陰","溫度":"20","體感溫度":"20","降雨機率":"30%","相對濕度":"83%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/10星期六","時間":"18:00","天氣狀況":"短暫雨","溫度":"18","體感溫度":"18","降雨機率":"30%","相對濕度":"88%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/10星期六","時間":"21:00","天氣狀況":"短暫雨","溫度":"18","體感溫度":"17","降雨機率":"40%","相對濕度":"91%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"00:00","天氣狀況":"短暫雨","溫度":"18","體感溫度":"17","降雨機率":"40%","相對濕度":"92%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"03:00","天氣狀況":"短暫雨","溫度":"17","體感溫度":"17","降雨機率":"30%","相對濕度":"93%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"06:00","天氣狀況":"短暫雨","溫度":"17","體感溫度":"16","降雨機率":"30%","相對濕度":"94%","蒲福風級":"3","風速(m\/s)":"5","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"09:00","天氣狀況":"陰","溫度":"18","體感溫度":"17","降雨機率":"30%","相對濕度":"91%","蒲福風級":"3","風速(m\/s)":"5","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"12:00","天氣狀況":"陰","溫度":"19","體感溫度":"17","降雨機率":"30%","相對濕度":"86%","蒲福風級":"4","風速(m\/s)":"6","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"15:00","天氣狀況":"陰","溫度":"18","體感溫度":"17","降雨機率":"20%","相對濕度":"85%","蒲福風級":"3","風速(m\/s)":"5","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"18:00","天氣狀況":"陰","溫度":"17","體感溫度":"16","降雨機率":"20%","相對濕度":"87%","蒲福風級":"3","風速(m\/s)":"5","風向":"東北風","舒適度":"稍有寒意"},{"日期":"12\/11星期日","時間":"21:00","天氣狀況":"陰","溫度":"17","體感溫度":"15","降雨機率":"20%","相對濕度":"87%","蒲福風級":"3","風速(m\/s)":"4","風向":"東北風","舒適度":"稍有寒意"}]

# %%
from flask import Flask
app = Flask(__name__)

import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

@app.route('/<town>')
def index(town):
    if not os.path.isfile('district.xlsx'):
        df=pd.read_excel("712693030RPKUP4RX.xlsx",header=3) #從第四列開始
        df=df[["縣市名稱","區里代碼","區鄉鎮名稱"]]
        df=df.drop_duplicates()
        df.to_excel('district.xlsx',encoding='utf-8',index=False)
    df_town=pd.read_excel('district.xlsx')
    town="新竹縣竹北市"
    dfs=df_town[(df_town["縣市名稱"]==town[0:3])&(df_town["區鄉鎮名稱"]==town[3:])]

    if len(dfs)>0:
        town_no=str(dfs.iloc[0,1])# 區里代碼
        url='https://www.cwb.gov.tw/V8/C/W/Town/MOD/3hr/'+town_no+'_3hr_PC.html?T=2022120917-1'
        geturl=requests.get(url)
        if geturl.status_code != 200:
            print("未成功訪問")
        soup=BeautifulSoup(geturl.text,'html.parser')
        all_data = soup.find_all("tr")

        measurement_columns=[]
        measurement_date=[]
        measurement_time=[]
        measurement_weather=[]
        measurement_temperature=[]
        measurement_bodyTemperature=[]
        measurement_rain=[]
        measurement_wet=[]
        measurement_wind=[]
        measurement_windS=[]
        measurement_windDirection=[]
        measurement_comfort=[]

        for x in range(len(all_data)):
            measurement_columns.append(all_data[x].th.text)
            if all_data[x].th.text=="日期":
                for y in range(1,len(all_data[x].find_all('th'))):
                    measurement_date.append(all_data[x].find_all('th')[y].text)
            if all_data[x].th.text=="時間":
                for y in range(1,len(all_data[x].find_all('th'))):
                    measurement_time.append(all_data[x].find_all('th')[y].text)
            if all_data[x].th.text=="天氣狀況":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_weather.append(all_data[x].find_all('td')[y].img.get("title"))
            if all_data[x].th.text=="溫度":
                for y in range(len(all_data[x].find_all('td'))):
                    temperature = all_data[x].find_all('td')[y].text[0:2]
                    measurement_temperature.append(temperature)
            if all_data[x].th.text=="體感溫度":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_bodyTemperature.append(all_data[x].find_all('td')[y].text[0:2])
            if all_data[x].th.text=="降雨機率":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_rain.append(all_data[x].find_all('td')[y].text)
                    # measurement_temperature.append(temperature)
            if all_data[x].th.text=="相對濕度":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_wet.append(all_data[x].find_all('td')[y].text)
            if all_data[x].th.text=="蒲福風級":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_wind.append(all_data[x].find_all('td')[y].text)
            if all_data[x].th.text=="風速(m/s)":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_windS.append(all_data[x].find_all('td')[y].text)
            if all_data[x].th.text=="風向":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_windDirection.append(all_data[x].find_all('td')[y].text)
            if all_data[x].th.text=="舒適度":
                for y in range(len(all_data[x].find_all('td'))):
                    measurement_comfort.append(all_data[x].find_all('td')[y].text) 
        import pandas as pd
        df=pd.DataFrame(columns=measurement_columns)

        temp_date=[]
        cnt=0
        for x in range(len(measurement_time)):
            if measurement_time[x] != "00:00":
                temp_date.append(measurement_date[cnt])
            else:
                cnt+=1
                temp_date.append(measurement_date[cnt])      
        

        measurement_rain2=[]
        for x in range(len(measurement_rain)):
            measurement_rain2.append(measurement_rain[x])
            measurement_rain2.append(measurement_rain[x])
        measurement_rain2=measurement_rain2[:len(measurement_rain2)-1]
        

        df["日期"]=temp_date
        df["時間"]=measurement_time
        df["天氣狀況"]=measurement_weather
        df["溫度"]=measurement_temperature
        df["體感溫度"]=measurement_bodyTemperature
        df["降雨機率"]=measurement_rain2
        df["相對濕度"]=measurement_wet
        df["蒲福風級"]=measurement_wind
        df["風速(m/s)"]=measurement_windS
        df["風向"]=measurement_windDirection
        df["舒適度"]=measurement_comfort
        return df.to_json(orient='records',force_ascii=False) #將所有資料用JSON格式回傳
    else:
        return "無此名稱"

if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [09/Dec/2022 19:42:15] "GET / HTTP/1.1" 404 -
# [2022-12-09 19:42:15,371] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "d:\MyFold\PYTHON\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "d:\MyFold\PYTHON\lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "d:\MyFold\PYTHON\lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "d:\MyFold\PYTHON\lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\17E5\AppData\Local\Temp\ipykernel_9948\2283467902.py", line 16, in index
#     df_town=pd.read_excel('district.xlsx')
# UnboundLocalError: local variable 'pd' referenced before assignment
# 127.0.0.1 - - [09/Dec/2022 19:42:15] "GET /favicon.ico HTTP/1.1" 500 -
